# %%
# !git clone https://github.com/TerrenceReinhardt/thesis_prototype
# %cd thesis_prototype
# Out:
# Cloning into 'thesis_prototype'...
# remote: Enumerating objects: 24, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 24 (delta 4), reused 20 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (24/24), 12.00 KiB | 4.00 MiB/s, done.
# Resolving deltas: 100% (4/4), done.
# /content/thesis_prototype

# %%
# !pip install -r requirements.txt
# !pip install openpyxl
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 608.4/608.4 kB 21.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 111.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 110.2 MB/s eta 0:00:00
# ...

# %%
import torch
print(torch.__version__)
print("CUDA:", torch.cuda.is_available())
# Out:
# 2.10.0+cu128
# CUDA: True

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-df3d7242-8be8-44a1-8860-be2261533693" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-df3d7242-8be8-44a1-8860-be2261533693">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os

os.makedirs("data/raw", exist_ok=True)
# !mv dataset.xlsx data/raw/dataset.xlsx

# %%
import pandas as pd

df = pd.read_excel("data/raw/dataset.xlsx")
print(df.head())
print(df.columns.tolist())
print(df.shape)
# Out:
#                  Date           User  \
# 0 2022-03-31 21:32:04  pikobar_jabar
# 1 2022-03-31 16:26:00     inewsdotid
# 2 2022-03-31 12:02:34      vdvc_talk
# 3 2022-03-30 21:23:10  pikobar_jabar
# 4 2022-03-30 18:28:57      tvOneNews
#
#                                                Tweet  sentiment
# 0  Ketahui informasi pembagian #PPKM di wilayah J...          1
# 1  Tempat Ibadah di Wilayah PPKM Level 1 Boleh Be...          1
# 2  Juru bicara Satgas Covid-19, Wiku Adisasmito m...          1
# 3  Ketahui informasi pembagian #PPKM di wilayah J...          1
# 4  Kementerian Agama menerbitkan Surat Edaran Nom...          1
# ['Date', 'User', 'Tweet', 'sentiment']
# (23644, 4)

# %%
print(df["sentiment"].value_counts())
# Out:
# sentiment
# 1    17706
# 2     3980
# 0     1958
# Name: count, dtype: int64

# %%
# !pwd
# !ls
# Out:
# /content
# data  sample_data

# %%
# %cd /content/thesis_prototype
# Out:
# [Errno 2] No such file or directory: '/content/thesis_prototype'
# /content

# %%
# !pwd
# !ls /content
# Out:
# /content
# data  sample_data

# %%
# %cd /content/thesis_prototype
# !ls
# !ls src
# Out:
# [Errno 2] No such file or directory: '/content/thesis_prototype'
# /content
# data  sample_data
# ls: cannot access 'src': No such file or directory

# %%
# %cd /content
# !git clone https://github.com/TerrenceReinhardt/thesis_prototype.git
# %cd /content/thesis_prototype
# !ls
# !ls src
# Out:
# /content
# Cloning into 'thesis_prototype'...
# remote: Enumerating objects: 24, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 24 (delta 4), reused 20 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (24/24), 12.00 KiB | 12.00 MiB/s, done.
# Resolving deltas: 100% (4/4), done.
# /content/thesis_prototype
# app.py	README.md  requirements.txt  src
# compare.py  data_loader.py  normalization.py  train.py
# config.py   __init__.py     preprocessing.py

# %%
# !pip install -r requirements.txt
# !pip install openpyxl
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 8.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 608.4/608.4 kB 39.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 93.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 82.7 MB/s eta 0:00:00
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8536e393-ccda-42c7-9d52-01227c36fd9c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8536e393-ccda-42c7-9d52-01227c36fd9c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os
os.makedirs("data/raw", exist_ok=True)
# !mv dataset.xlsx data/raw/dataset.xlsx

# %%
import pandas as pd
df = pd.read_excel("data/raw/dataset.xlsx")
print(df.columns.tolist())
print(df.shape)
# Out:
# ['Date', 'User', 'Tweet', 'sentiment']
# (23644, 4)

# %%
# !pwd
# !ls
# !ls src
# Out:
# /content/thesis_prototype
# app.py	data  README.md  requirements.txt  src
# compare.py  data_loader.py  normalization.py  __pycache__
# config.py   __init__.py     preprocessing.py  train.py

# %%
# !python -c "import src.train; print('src.train kebaca')"
# Out:
# src.train kebaca

# %%
# !python -c "from src.train import train; print('mulai'); train()"
# Out:
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
# ImportError: cannot import name 'train' from 'src.train' (/content/thesis_prototype/src/train.py)

# %%
# !ls -l src/train.py
# Out:
# -rw-r--r-- 1 root root 0 Apr 20 13:03 src/train.py

# %%
# !wc -l src/train.py
# Out:
# 0 src/train.py

# %%
# %cd /content/thesis_prototype
# !git checkout update
# !ls src
# !wc -l src/train.py
# Out:
# /content/thesis_prototype
# Branch 'update' set up to track remote branch 'update' from 'origin'.
# Switched to a new branch 'update'
# compare.py  data_loader.py  normalization.py  __pycache__
# config.py   __init__.py     preprocessing.py  train.py
# 258 src/train.py

# %%
# !python -m src.train
# Out:
# [train] Using device  : cuda
# [train] Model         : bert-base-multilingual-cased  (mBERT)
# [preprocessing] Total samples after cleaning : 23,486
# [preprocessing] Label distribution:
# label
# 0     1943
# 1    17598
# 2     3945
# Name: count, dtype: int64
# [preprocessing] train: 16,440 samples
# [preprocessing] val  : 3,523 samples
# [preprocessing] test : 3,523 samples
# config.json: 100% 625/625 [00:00<00:00, 2.49MB/s]
# ...
# tokenizer_config.json: 100% 49.0/49.0 [00:00<00:00, 200kB/s]
# vocab.txt: 996kB [00:00, 1.36MB/s]
# tokenizer.json: 1.96MB [00:01, 1.53MB/s]
# [data_loader] train: 16,440 samples | 1028 batches
# [data_loader] val  : 3,523 samples |  221 batches
# [data_loader] test : 3,523 samples |  221 batches
# model.safetensors: 100% 714M/714M [00:05<00:00, 132MB/s]
# Loading weights: 100% 199/199 [00:00<00:00, 1206.21it/s, Materializing param=bert.pooler.dense.weight]
# BertForSequenceClassification LOAD REPORT from: bert-base-multilingual-cased
# ...

# %%
# !ls results
# Out:
# classification_report_mBERT.txt  history_mBERT.json
# confusion_matrix_mBERT.png	 training_curve_mBERT.png

# %%
from google.colab import files

files.download('results/classification_report_mBERT.txt')
files.download('results/training_curve_mBERT.png')
files.download('results/confusion_matrix_mBERT.png')
files.download('results/history_mBERT.json')

# %%
# !zip -r results.zip results
from google.colab import files
files.download('results.zip')
# Out:
#   adding: results/ (stored 0%)
#   adding: results/confusion_matrix_mBERT.png (deflated 14%)
#   adding: results/history_mBERT.json (deflated 57%)
#   adding: results/training_curve_mBERT.png (deflated 9%)
#   adding: results/classification_report_mBERT.txt (deflated 58%)

# %%
# !zip -r models.zip models
from google.colab import files
files.download('models.zip')
# Out:
#   adding: models/ (stored 0%)
#   adding: models/best_mBERT_model/ (stored 0%)
#   adding: models/best_mBERT_model/model.safetensors (deflated 7%)
#   adding: models/best_mBERT_model/tokenizer.json (deflated 67%)
#   adding: models/best_mBERT_model/config.json (deflated 56%)
#   adding: models/best_mBERT_model/tokenizer_config.json (deflated 43%)
